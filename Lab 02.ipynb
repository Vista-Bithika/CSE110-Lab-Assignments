# %%
#Task 01

A=int(input("Enter a number: "))
B=int(input("Enter a number:"))
Sum= A+B
Product= A*B
Difference=A-B
print("Sum =", Sum)
print( "Product =", Product)
print("Difference =", Difference)
# Out:
# Enter a number: 4
# Enter a number:5
# Sum = 9
# Product = 20
# Difference = -1

# %%
#Task2
import math
radius=int(input())
area=math.pi*math.pow(radius,2)
circumference=2*math.pi*radius
print("Area is", area )
print("Circumference is", circumference)
# Out:
# 4
# Area is 50.26548245743669
# Circumference is 25.132741228718345

# %%
#Task3
a=int(input("Enter the first number: "))
b=int(input("Enter the second number: "))
if a>b :
  print ("First is greater")
elif b>a :
    print("Second is greater")
else :
    print ("The numbers are equal")
# Out:
# Enter the first number: 7
# Enter the second number: 3
# First is greater

# %%
#task4
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
if a>b :
  print(a-b)
else :
  print(b-a)
# Out:
# Enter a number: -40
# Enter a number: -4
# 36

# %%
#task5
n=int(input("Enter a number: "))
if(n%2==0):
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a number10
# The number is even

# %%
#Task6
a=int(input())
if a%2==0 or a%5==0:
  print(a)
else:
  print("Not a multiple of 2 OR 5")
# Out:
# 3
# Not a multiple of 2 OR 5

# %%
#Task7
a=int(input("Enter a number: "))
if a%2==0 and a%5==0 : 
  print("Multiple of 2 and 5 both")
elif a%2==0 or a%5==0 :
  print(a)
else :
  print("Not a multiple we want")
# Out:
# Enter a number: 6
# 6

# %%
#task8
number=int(input("Enter a number: "))
if number%2==0 and number%5==0 : 
  print(number)
else :
  print("Not a multiple of 2 and 5 both")
# Out:
# Enter a number: 15
# Not a multiple of 2 and 5 both

# %%
#Task9
time=int(input("Enter time in seconds: "))
remain=time
if(remain>3600):
    print("Hours:", remain//3600, end=" ")
remain=remain%3600
if(remain>60):
    print("Minutes:", remain//60,end=" ")
remain=remain%60
print("Seconds:", remain)
# Out:
# Enter time in seconds: 10000
# Hours: 2 Minutes: 46 Seconds: 40

# %%
#Task10
hours=int(input("Enter hours: "))
if hours<0:
    print("Hour can not be negative")
elif hours<=40:
    print(hours*200)
elif hours>40:
    print(8000+(hours-40)*300)
elif hours>168:
    print("Impossible to work more than 168 hours weekly")
# Out:
# Enter hours: 100
# 26000

# %%
#task11
import math
s=int(input("Enter a number: "))
if s<100:
  L=3000-(125*math.pow(s,2))
  print("result=", L)
elif s>=100 :
  L2=12000/(4+math.pow(s,2)/14900)
  print("result_2 is=", L2)
# Out:
# Enter a number: 120
# result_2 is= 2416.2162162162163

# %%
#Task12
hour=int(input("enter time: "))
if hour<0 and hour>24 :
  print("Wrong time")
elif hour>=4 and hour<=6 :
  print("Breakfast")
elif hour>=12 and hour<=13 :
  print("Lunch")
elif hour>=16 and hour<=17 :
  print("Snacks")
elif hour>=19 and hour<=20 :
  print("Dinner")
else :
  print("Patience is a virtue")
# Out:
# enter time: 4
# Brakfast

# %%
#task13
Marks=int(input("Enter a number: "))
if (Marks<0 or Marks>100):
    print("Invalid")
if Marks>90:
    print("A")
elif Marks>=80 and Marks<=89:
    print("B")
elif Marks>=70 and Marks<=79:
    print("C")
elif Marks>=60 and Marks<=69:
    print("D")
elif Marks>=50 and Marks<=59:
    print("E")
elif Marks<50 :
    print("F")
# Out:
# Enter a number: 79
# C

# %%
#Task14
s=int(input("Enter a distance:"))
t=int(input("Enter a time:"))
v= (s*3600)/(t*1000)
print(v,"km/h")
if v<60:
    print("Too slow. Needs more changes.")
elif v>=60 and v<=90:
    print("Velocity is okay. The car is ready!")
elif v>90:
    print("Too fast. Only a few changes should suffice.")
# Out:
# Enter a distance:25400
# Enter a time:3600
# 25.4 km/h
# Too slow. Needs more changes

# %%
#Task15
a=float(input())
b=int(input())
if (a>=3.80 and a<=3.89) and b>=30:
    print("The student is eligible for a waiver of 25 percent.")
elif (a>=3.90 and a<=3.94) and b>=30:
    print("The student is eligible for a waiver of 50 percent.")
elif (a>=3.95 and a<=3.99) and b>=30:
    print("The student is eligible for a waiver of 75 percent.")
elif a==4.0:
    print("The student is eligible for a waiver of 100 percent.")
else:
    print("The student is not eligible for a waiver.")
# Out:
# 3.79
# 24
# The student is not eligible for a waiver
